# %% [markdown]
# # Verificar se um grafo é conexo
# ---

# %% [markdown]
# ### Caso não direcionado

# %%
from parte2.graph import Graph
from parte2.graph_llm import Graph as LLMGraph
from parte2.util import read_file
from IPython.display import Image, display

graph = Graph(file_path='input1.txt')
print(f'Connected: {graph.check_connected()}')

graph_l = LLMGraph(file_path='input1.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("neato").create_png()))
# Out:
# Connected: False
# Connected (LLM): False

# %%
graph = Graph(file_path='input1c.txt')
print(f'Connected: {graph.check_connected()}')

graph_l = LLMGraph(file_path='input1c.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("neato").create_png()))
# Out:
# Connected: True
# Connected (LLM): True

# %%
graph = Graph(file_path='input3.txt')
print(f'Connected: {graph.check_connected()}')


graph_l = LLMGraph(file_path='input3.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("dot").create_png()))
# Out:
# Connected: True
# Connected (LLM): True

# %%
graph = Graph(file_path='input3.2x1.txt')
print(f'Connected: {graph.check_connected()}')


graph_l = LLMGraph(file_path='input3.2x1.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("dot").create_png()))
# Out:
# Connected: False
# Connected (LLM): False

# %% [markdown]
# ### Caso direcionado

# %%
graph = Graph(file_path='input1d.txt')
print(f'Connected: {graph.check_connected()}')


graph_l = LLMGraph(file_path='input1d.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("dot").create_png()))
# Out:
# Connected: True
# Connected (LLM): True

# %%
graph = Graph(file_path='input1d2.txt')
print(f'Connected: {graph.check_connected()}')


graph_l = LLMGraph(file_path='input1d2.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("dot").create_png()))
# Out:
# Connected: False
# Connected (LLM): False

# %%
graph = Graph(file_path='input3.2.txt')
print(f'Connected: {graph.check_connected()}')


graph_l = LLMGraph(file_path='input3.2.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("dot").create_png()))
# Out:
# Connected: True
# Connected (LLM): True

# %%
graph = Graph(file_path='input3.2x.txt')
print(f'Connected: {graph.check_connected()}')


graph_l = LLMGraph(file_path='input3.2x.txt')
print(f'Connected (LLM): {graph.check_connected()}')

display(Image(graph.to_pydot("dot").create_png()))
# Out:
# Connected: False
# Connected (LLM): False
